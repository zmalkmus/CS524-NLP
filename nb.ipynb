# %%
from Book_module.Book import Book

# %%
book_one = Book('books/book_temple_of_silence.txt')
book_two = Book('books/book_secret_garden.txt')
book_three = Book('books/book_the_hammer_of_god.txt')
book_four = Book('books/book_the_wrong_shape.txt')
# Out:
# [__init__]: Initializing book from file: books/book_temple_of_silence.txt
# [__init__]: Initializing book from file: books/book_secret_garden.txt
# [__init__]: Initializing book from file: books/book_the_hammer_of_god.txt
# [__init__]: Initializing book from file: books/book_the_wrong_shape.txt

# %%
book_one.pre_process()
book_one.feature_extraction()
book_two.pre_process()
book_two.feature_extraction()
book_three.pre_process()
book_three.feature_extraction()
book_four.pre_process()
book_four.feature_extraction()
# Out:
# get_book(): Text obtained from file 'books/book_temple_of_silence.txt'.
# Warning: Start of Project Gutenberg header not found.
# Warning: End of Project Gutenberg footer not found.
# Plot Structure Identification:
#
# Exposition (Sentences 0 to 0):
# Start: VII ....
# End: VII ....
#
# Rising Action (Sentences 0 to 78):
# Start: VII ....
# End: First thing I ever know you didnt know cry the exuberant Harry ....
#
# Climax (Sentences 78 to 79):
# Start: First thing I ever know you didnt know cry the exuberant Harry ....
# End: And there more besides go on Horne who seem to have suddenly find his tongu...
#
# Falling Action (Sentences 79 to 451):
# Start: And there more besides go on Horne who seem to have suddenly find his tongu...
# End: ....
#
# Resolution (Sentences 451 to 501):
# Start: ....
# End: Why you lunatic cry Henry in tone of ring sincerity you dont suppose you be...
# get_book(): Text obtained from file 'books/book_secret_garden.txt'.
# Warning: Start of Project Gutenberg header not found.
# Warning: End of Project Gutenberg footer not found.
# Plot Structure Identification:
#
# Exposition (Sentences 0 to 0):
# Start: The Secret Garden Valentin Chief of the Paris Police be late for his dinner...
# End: The Secret Garden Valentin Chief of the Paris Police be late for his dinner...
#
# Rising Action (Sentences 0 to 230):
# Start: The Secret Garden Valentin Chief of the Paris Police be late for his dinner...
# End: I run outside the house to find any trace of him and I find one and a big t...
#
# Climax (Sentences 230 to 231):
# Start: I run outside the house to find any trace of him and I find one and a big t...
# End: What do you mean ?...
#
# Falling Action (Sentences 231 to 394):
# Start: What do you mean ?...
# End: repeat Paul reflectively ....
#
# Resolution (Sentences 394 to 437):
# Start: repeat Paul reflectively ....
# End: say Neil staring ....
# get_book(): Text obtained from file 'books/book_the_hammer_of_god.txt'.
# Warning: Start of Project Gutenberg header not found.
# Warning: End of Project Gutenberg footer not found.
# Plot Structure Identification:
#
# Exposition (Sentences 0 to 7):
# Start: The Hammer of God The little village of Bohun Beacon be perch on a hill so ...
# End: Norman his elder brother be by no mean devout and be sit in even dress on t...
#
# Rising Action (Sentences 7 to 303):
# Start: Norman his elder brother be by no mean devout and be sit in even dress on t...
# End: First say Father Paul quietly the thing be quite in your own province ....
#
# Climax (Sentences 303 to 304):
# Start: First say Father Paul quietly the thing be quite in your own province ....
# End: It be a matter of physical science ....
#
# Falling Action (Sentences 304 to 327):
# Start: It be a matter of physical science ....
# End: And yet when they saw it from below it spring like a fountain at the star a...
#
# Resolution (Sentences 327 to 363):
# Start: And yet when they saw it from below it spring like a fountain at the star a...
# End: Listen to me he say after a short pause ....
# get_book(): Text obtained from file 'books/book_the_wrong_shape.txt'.
# Warning: Start of Project Gutenberg header not found.
# Warning: End of Project Gutenberg footer not found.
# Plot Structure Identification:
#
# Exposition (Sentences 0 to 39):
# Start: The Wrong Shape Certain of the great road go north out of London continue f...
# End: say the doctor coolly ....
#
# Rising Action (Sentences 39 to 0):
# Start: say the doctor coolly ....
# End: The Wrong Shape Certain of the great road go north out of London continue f...
#
# Climax (Sentences 0 to 1):
# Start: The Wrong Shape Certain of the great road go north out of London continue f...
# End: Here will be a group of shop follow by a fenced field or paddock and then a...
#
# Falling Action (Sentences 1 to 355):
# Start: Here will be a group of shop follow by a fenced field or paddock and then a...
# End: Can you think of anything hardly big than a comma which the man with hell i...
#
# Resolution (Sentences 355 to 394):
# Start: Can you think of anything hardly big than a comma which the man with hell i...
# End: Leonard lay down in the conservatory and I come through the study ....

# %%
print(book_one.character_mentions_all)
# print(book_two.character_mentions_all)
# print(book_three.character_mentions_all)
print(book_one.character_mentions_first)
print(book_one.text_tokenized)
# Out:
# {'Horne': 63, 'Harold': 7, 'Ashton': 3, 'Saltoun': 10, 'Verner': 36, 'Gryce': 13, 'Wilkins': 2}
# {'Horne': 8, 'Harold': 5, 'Ashton': 194, 'Saltoun': 391, 'Verner': 535, 'Gryce': 1422, 'Wilkins': 1799}
# ['VII', 'THE', 'TEMPLE', 'OF', 'SILENCE', 'Harold', 'cultivate', 'friendship', 'Horne', 'especially', 'saw', 'something', 'social', 'setting', 'conscious', 'certain', 'solitude', 'sociability', 'seem', 'always', 'meet', 'relation', 'never', 'meet', 'family', 'perhaps', 'would', 'truer', 'say', 'saw', 'much', 'family', 'nothing', 'home', 'cousin', 'connection', 'ramify', 'like', 'labyrinth', 'govern', 'class', 'Great', 'Britain', 'seem', 'good', 'least', 'goodhumored', 'term', 'Horne', 'remarkable', 'curious', 'impersonal', 'information', 'interest', 'touch', 'sort', 'topic', 'one', 'could', 'sometimes', 'fancy', 'culture', 'like', 'colorless', 'fair', 'mustache', 'pale', 'drooping', 'feature', 'neutral', 'nature', 'chameleon', 'Anyhow', 'could', 'always', 'get', 'viceroy', 'Cabinet', 'Ministers', 'great', 'men', 'responsible', 'great', 'department', 'talk', 'subject', 'branch', 'study', 'seriously', 'concern', 'thus', 'could', 'converse', 'Minister', 'War', 'silkworm', 'Minister', 'Education', 'detective', 'story', 'Minister', 'Labor', 'Limoges', 'enamel', 'Minister', 'Missions', 'Moral', 'Progress', 'correct', 'title', 'pantomime', 'boy', 'last', 'four', 'decade', 'first', 'first', 'cousin', 'second', 'second', 'cousin', 'third', 'brotherinlaw', 'fourth', 'uncle', 'marriage', 'conversational', 'versatility', 'certainly', 'serve', 'one', 'sense', 'create', 'happy', 'family', 'Harold', 'never', 'seem', 'get', 'glimpse', 'domestic', 'interior', 'men', 'middle', 'class', 'accustom', 'friendship', 'indeed', 'foundation', 'friendship', 'love', 'everything', 'else', 'sane', 'stable', 'society', 'wonder', 'whether', 'Horne', 'orphan', 'child', 'therefore', 'something', 'like', 'start', 'find', 'Horne', 'brother', 'much', 'prosperous', 'powerful', 'though', 'hardly', 'Harold', 'think', 'entertaining', 'Sir', 'Henry', 'half', 'alphabet', 'name', 'something', 'Foreign', 'Office', 'far', 'tremendous', 'Foreign', 'Secretary', 'apparently', 'run', 'family', 'seem', 'another', 'brother', 'Ashton', 'India', 'rather', 'tremendous', 'Viceroy', 'Sir', 'Henry', 'heavy', 'handsome', 'edition', 'brother', 'brow', 'equally', 'bald', 'much', 'smooth', 'courteous', 'shade', 'patronize', 'Harold', 'even', 'Harold', 'fancy', 'Horne', 'well', 'latter', 'gentleman', 'many', 'intuition', 'halfformed', 'thought', 'others', 'glance', 'topic', 'come', 'away', 'great', 'house', 'Berkeley', 'Square', 'dont', 'know', 'observe', 'quietly', 'fool', 'family', 'must', 'clever', 'family', 'say', 'harold', 'smile', 'gracefully', 'express', 'replied', 'Horne', 'best', 'literary', 'training', 'Well', 'perhaps', 'exaggeration', 'say', 'fool', 'family', 'enough', 'say', 'failure', 'family', 'seem', 'queer', 'fail', 'especially', 'remark', 'journalist', 'say', 'examination', 'fail', 'politics', 'reply', 'friend', 'stand', 'Parliament', 'quite', 'young', 'man', 'get', 'enormous', 'majority', 'loud', 'cheer', 'chair', 'round', 'town', 'since', 'course', 'Ive', 'rather', 'cloud', 'Im', 'afraid', 'dont', 'quite', 'understand', 'course', 'answer', 'Harold', 'laughing', 'part', 'isnt', 'worth', 'understand', 'say', 'Horne', 'matter', 'fact', 'old', 'chap', 'part', 'rather', 'odd', 'interesting', 'quite', 'detective', 'story', 'way', 'well', 'first', 'lesson', 'modern', 'politics', 'make', 'like', 'Ill', 'tell', 'following', 'recast', 'less', 'allusive', 'conversational', 'manner', 'story', 'tell', 'Nobody', 'privilege', 'late', 'year', 'meet', 'Sir', 'Henry', 'would', 'believe', 'ever', 'call', 'Harry', 'indeed', 'boyish', 'enough', 'boy', 'serenity', 'shone', 'life', 'take', 'form', 'gravity', 'take', 'form', 'gayety', 'friend', 'would', 'say', 'ripe', 'maturity', 'young', 'youth', 'enemy', 'would', 'say', 'still', 'light', 'mind', 'long', 'light', 'hearted', 'case', 'whole', 'story', 'Horne', 'tell', 'arise', 'accident', 'make', 'young', 'Harry', 'private', 'secretary', 'Lord', 'Saltoun', 'Hence', 'late', 'connection', 'Foreign', 'Office', 'indeed', 'come', 'sort', 'legacy',  ...
